# %%
import os
import json

# result_dir = 'output'
# result_dir = './output/SLOWFAST_32x2_R50_SHORT_SCRATCH'
# result_dir = './output/SLOWFAST_32x2_R50_SHORT_SCRATCH_EVAL_GT'
result_dir = './output/SLOWFAST_32x2_R50_SHORT_GT'
# result_dir = './output/BASELINE_32x2_R50_SHORT'
# result_dir = './output/BASELINE_32x2_R50_SHORT_SCRATCH'
# result_dir = './output/BASELINE_32x2_R50_SHORT_SCRATCH_EVAL_GT'
# result_dir = './output/BASELINE_32x2_R50_SHORT_GT_R50NOTFROZEN'


# result_json_name = 'all_results_vidor_checkpoint_epoch_00007.pyth_proposal.json'
# result_json_name = 'all_results_vidor_checkpoint_epoch_00020.pyth_debug.json'
# result_json_name = 'all_results_vidor_checkpoint_epoch_00020.pyth.json'
# result_json_name = 'all_results_vidor_checkpoint_epoch_00020.pyth_proposal.json'
result_json_name = 'all_results_vidor_checkpoint_epoch_00005.pyth_proposal.json'
# result_json_name = 'all_results_vidor__proposal.json'
# result_json_name = 'all_results_vidor_checkpoint_epoch_00014.pyth.json'
# result_json_name = 'all_results_vidor_checkpoint_epoch_00014.pyth_debug_proposal.json'

with open(os.path.join(result_dir, result_json_name), 'r') as f:
    all_results = json.load(f)

# %%
len(all_results)
# Out:
# 22976

# %%
all_results[0].keys()
# Out:
# dict_keys(['preds_score', 'preds', 'preds_bbox_pair_ids', 'proposal_scores', 'proposal_boxes', 'proposal_classes', 'gt_boxes', 'gt_action_labels', 'gt_obj_classes', 'gt_bbox_pair_ids'])

# %%
idx = 0
for key in all_results[idx].keys():
    print(f'shape of {key}: {len(all_results[idx][key])}')
# Out:
# shape of preds_score: 1
# shape of preds: 1
# shape of preds_bbox_pair_ids: 1
# shape of proposal_scores: 2
# shape of proposal_boxes: 2
# shape of proposal_classes: 2
# shape of gt_boxes: 2
# shape of gt_action_labels: 1
# shape of gt_obj_classes: 2
# shape of gt_bbox_pair_ids: 1

# %%
def bbox_iou(boxA, boxB):
    # determine the (x, y)-coordinates of the intersection rectangle
    xA = max(boxA[0], boxB[0])
    yA = max(boxA[1], boxB[1])
    xB = min(boxA[2], boxB[2])
    yB = min(boxA[3], boxB[3])

    # compute the area of intersection rectangle
    interArea = abs(max((xB - xA, 0)) * max((yB - yA), 0))
    if interArea == 0:
        return 0
    
    # compute the area of both the prediction and ground-truth
    # rectangles
    boxAArea = abs((boxA[2] - boxA[0]) * (boxA[3] - boxA[1]))
    boxBArea = abs((boxB[2] - boxB[0]) * (boxB[3] - boxB[1]))

    # compute the intersection over union by taking the intersection
    # area and dividing it by the sum of prediction + ground-truth
    # areas - the interesection area
    iou = interArea / float(boxAArea + boxBArea - interArea)

    # return the intersection over union value
    return iou

# %%
from tqdm import tqdm

tp, fp, scores, sum_gt = {}, {}, {}, {}

# Construct dictionaries of triplet class 
for result in tqdm(all_results):
    bbox_pair_ids = result['gt_bbox_pair_ids']
    
    for idx, action_label in enumerate(result['gt_action_labels']):
        # action_label != 0.0
        action_label_idxs = [i for i in range(50) if action_label[i] == 1.0]
        for action_label_idx in action_label_idxs:
            subject_label_idx = 0 # person idx = 0
            object_label_idx = int(result['gt_obj_classes'][bbox_pair_ids[idx][1]][1])
            triplet_class = (subject_label_idx, action_label_idx, object_label_idx)
            
            if triplet_class not in tp: # should also not exist in fp, scores & sum_gt
                tp[triplet_class] = []
                fp[triplet_class] = []
                scores[triplet_class] = []
                sum_gt[triplet_class] = 0
            sum_gt[triplet_class] += 1
            
# delete triplet classes that have less than 25 instances
triplet_classes_to_delete = []
for triplet_class, count in sum_gt.items():
    if count < 25:
        triplet_classes_to_delete.append(triplet_class)

for triplet_class in triplet_classes_to_delete:
    del tp[triplet_class], fp[triplet_class], scores[triplet_class], sum_gt[triplet_class]

# Collect true positive, false positive & scores
import math
correct_det_count = correct_hoi_count = total_det_count = 0
at_least_one_pair_bbox_detected_count = total_count = 0
for result in tqdm(all_results): # for each keyframe
    preds_bbox_pair_ids = result['preds_bbox_pair_ids']
    gt_bbox_pair_ids = result['gt_bbox_pair_ids']
    gt_bbox_pair_matched = set()
    
    # take only top 100 confident triplets
#     preds_scores = [
#         (math.log(result['preds_score'][i][j]) + \
#          math.log(result['proposal_scores'][preds_bbox_pair_ids[i][0]][1]) + \
#          math.log(result['proposal_scores'][preds_bbox_pair_ids[i][1]][1]), i, j) 
#         for i in range(len(result['preds_score'])) for j in range(len(result['preds_score'][i]))
#     ]
    preds_scores = [
        (math.log(all_preds_score[idx][i][j] if all_preds_score[idx][i][j] > 0 else 1e-300) + \
        math.log(all_proposal_scores[idx][preds_bbox_pair_ids[i][0]][1] if all_proposal_scores[idx][preds_bbox_pair_ids[i][0]][1] > 0 else 1e-300) + \
        math.log(all_proposal_scores[idx][preds_bbox_pair_ids[i][1]][1] if all_proposal_scores[idx][preds_bbox_pair_ids[i][1]][1] > 0 else 1e-300), i, j) 
        for i in range(len(all_preds_score[idx])) for j in range(len(all_preds_score[idx][i]))
    ]
    preds_scores.sort(reverse=True)
    preds_scores = preds_scores[:100]
    
    at_least_one_pair_bbox_detected = False
    
    for score, i, j in preds_scores: # for each HOI prediction, i-th pair and j-th action
        pred_sub_cls = int(result['proposal_classes'][preds_bbox_pair_ids[i][0]][1])
        pred_obj_cls = int(result['proposal_classes'][preds_bbox_pair_ids[i][1]][1])
        pred_rel_cls = j
        
        triplet_class = (pred_sub_cls, pred_rel_cls, pred_obj_cls)
        if triplet_class not in tp:
            continue
        
        pred_sub_box = result['proposal_boxes'][preds_bbox_pair_ids[i][0]][1:]
        pred_obj_box = result['proposal_boxes'][preds_bbox_pair_ids[i][1]][1:]
        is_match = False
        max_ov = max_gt_id = 0
        for k, gt_bbox_pair_id in enumerate(gt_bbox_pair_ids):  # for each ground truth HOI
            gt_sub_cls = int(result['gt_obj_classes'][gt_bbox_pair_id[0]][1])
            gt_obj_cls = int(result['gt_obj_classes'][gt_bbox_pair_id[1]][1])
            gt_rel_cls = result['gt_action_labels'][k][j]
            
            gt_sub_box = result['gt_boxes'][gt_bbox_pair_id[0]][1:]
            gt_obj_box = result['gt_boxes'][gt_bbox_pair_id[1]][1:]
            sub_ov = bbox_iou(gt_sub_box, pred_sub_box)
            obj_ov = bbox_iou(gt_obj_box, pred_obj_box)
            
            # import pdb; pdb.set_trace()
            
            if gt_sub_cls == pred_sub_cls and gt_obj_cls == pred_obj_cls and sub_ov >= 0.5 and obj_ov >= 0.5:
                correct_det_count += 1
                if not at_least_one_pair_bbox_detected:
                    at_least_one_pair_bbox_detected = True
                    at_least_one_pair_bbox_detected_count += 1
                    
                if gt_rel_cls == 1.0:
                    is_match = True
                    correct_hoi_count += 1
                    min_ov_cur = min(sub_ov, obj_ov)
                    if min_ov_cur > max_ov:
                        max_ov = min_ov_cur
                        max_gt_id = k
#                     print(f'a pair of bbox correctly localized and detected predicate is correct!')
#                     print(f'Current correct HOI/correct detection ratio: {correct_hoi_count/correct_det_count:5f}')
                else:
                    pass
#                     print(f'a pair of bbox correctly localized and detected but predicate is not correct!')
#                     print(f'Current correct HOI/correct detection ratio: {correct_hoi_count/correct_det_count:5f}')
            total_det_count += 1
            # print(f'Current detection/total detection ratio: {correct_det_count/total_det_count:5f}')
        
        if is_match and max_gt_id not in gt_bbox_pair_matched:
            tp[triplet_class].append(1)
            fp[triplet_class].append(0)
            gt_bbox_pair_matched.add(max_gt_id)
        else:
            tp[triplet_class].append(0)
            fp[triplet_class].append(1)
        scores[triplet_class].append(score)
    total_count += 1
#     print(f'Current at_least_one_pair_bbox_detected ratio: {at_least_one_pair_bbox_detected_count} / {total_count} = {at_least_one_pair_bbox_detected_count/total_count:5f}')

print(f'[Final] correct HOI/correct detection ratio: {correct_hoi_count/correct_det_count:5f}')
print(f'[Final] correct detection/total detection ratio: {correct_det_count/total_det_count:5f}')
print(f'[Final] at_least_one_pair_bbox_detected ratio: {at_least_one_pair_bbox_detected_count} / {total_count} = {at_least_one_pair_bbox_detected_count/total_count:5f}')
    
# for result in all_results:
#     bbox_pair_ids = result['bbox_pair_ids']
#     import pdb; pdb.set_trace()
# #     result['preds_score']
    
#     for idx, score in enumerate(result['preds_score']):
#         pass
        
# print('tp:', tp)
# print('fp:', fp)
# print('scores:', scores)
# Out:
# 100%|██████████| 22976/22976 [00:01<00:00, 14589.04it/s]
# 100%|██████████| 22976/22976 [01:47<00:00, 214.04it/s]
# [Final] correct HOI/correct detection ratio: 0.128676
# [Final] correct detection/total detection ratio: 0.094634
# [Final] at_least_one_pair_bbox_detected ratio: 21994 / 22976 = 0.957260

# %%
import pickle
with open('slowfast/datasets/vidor/idx_to_pred.pkl', 'rb') as f:
    idx_to_pred = pickle.load(f)
with open('slowfast/datasets/vidor/idx_to_obj.pkl', 'rb') as f:
    idx_to_obj = pickle.load(f)

# %%
print('Number of triplet class:', len(tp))
sorted_tp = sorted([(key, len(value)) for key, value in tp.items()], key=lambda key_value: key_value[1], reverse=True)
for triplet, count in sorted_tp:
    s, p, o = triplet
    print(f'({idx_to_obj[s]}, {idx_to_pred[p]}, {idx_to_obj[o]}): {count}')

# for key, values in tp.items():
#     print(key, len(values))
# Out:
# Number of triplet class: 242
# (person, next_to, person): 97363
# (person, in_front_of, person): 95017
# (person, behind, person): 79212
# (person, watch, person): 70373
# (person, above, person): 46614
# (person, away, person): 40690
# (person, towards, person): 39913
# (person, lean_on, person): 37531
# (person, hold, person): 35204
# (person, speak_to, person): 25161
# (person, hug, person): 24192
# (person, hold_hand_of, person): 23806
# (person, carry, person): 22002
# (person, beneath, person): 18998
# (person, caress, person): 15025
# (person, push, person): 14082
# (person, touch, person): 12814
# (person, pull, person): 12675
# (person, press, person): 12667
# (person, feed, person): 11621
# (person, hit, person): 9655
# (person, lift, person): 8603
# (person, pat, person): 8505
# (person, kiss, person): 7986
# (person, point_to, person): 7764
# (person, clean, person): 7586
# (person, wave_hand_to, person): 7513
# (person, next_to, toy): 6881
# (person, in_front_of, toy): 6880
# (person, behind, toy): 6877
# (person, watch, toy): 6863
# (person, towards, toy): 6597
# (person, away, toy): 6588
# (person, hold, toy): 6291
# (person, above, toy): 6121
# (person, next_to, table): 6015
# (person, lean_on, toy): 6009
# (person, in_front_of, table): 5981
# (person, next_to, guitar): 5629
# (person, ride, toy): 5392
# (person, in_front_of, guitar): 5351
# (person, behind, guitar): 5318
# (person, beneath, toy): 4941
# (person, inside, toy): 4334
# (person, in_front_of, sofa): 4188
# (person, push, toy): 4166
# (person, next_to, sofa): 4156
# (person, next_to, chair): 4096
# (person, watch, guitar): 4074
# (person, in_front_of, chair): 4057
# (person, above, table): 3965
# (person, press, toy): 3913
# (person, touch, toy): 3887
# (person, behind, sofa): 3663
# (person, lean_on, table): 3657
# (person, away, sofa): 3286
# (person, towards, sofa): 3280
# (person, behind, chair): 3279
# (person, play(instrument), guitar): 3270
# (person, lean_on, sofa): 3072
# (person, above, sofa): 3054
# (person, bite, toy): 3020
# (person, drive, toy): 2950
# (person, grab, toy): 2915
# (person, towards, table): 2881
# (person, next_to, cup): 2868
# (person, away, table): 2828
# (person, hold, guitar): 2792
# (person, point_to, toy): 2577
# (person, watch, cup): 2455
# (person, in_front_of, screen/monitor): 2292
# (person, next_to, screen/monitor): 2219
# (person, watch, screen/monitor): 2096
# (person, behind, screen/monitor): 2093
# (person, next_to, ball/sports_ball): 1998
# (person, in_front_of, ball/sports_ball): 1960
# (person, hold, cup): 1910
# (person, away, screen/monitor): 1851
# (person, towards, screen/monitor): 1837
# (person, next_to, dog): 1792
# (person, in_front_of, dog): 1788
# (person, watch, dog): 1774
# (person, behind, dog): 1774
# (person, towards, cup): 1766
# (person, away, cup): 1760
# (person, above, chair): 1746
# (person, towards, dog): 1724
# (person, next_to, bottle): 1723
# (person, away, dog): 1721
# (person, away, chair): 1660
# (person, towards, chair): 1642
# (person, behind, ball/sports_ball): 1638
# (person, hold, dog): 1606
# (person, next_to, baby_seat): 1563
# (person, in_front_of, baby_seat): 1563
# (person, behind, baby_seat): 1555
# (person, watch, ball/sports_ball): 1543
# (person, hold, screen/monitor): 1528
# (person, above, baby_seat): 1489
# (person, above, screen/monitor): 1473
# (person, lean_on, baby_seat): 1467
# (person, lean_on, chair): 1464
# (person, next_to, dish): 1417
# (person, towards, ball/sports_ball): 1335
# (person, away, ball/sports_ball): 1325
# (person, hold, ball/sports_ball): 1250
# (person, caress, dog): 1203
# (person, inside, baby_seat): 1182
# (person, pull, dog): 1181
# (person, next_to, bicycle): 1141
# (person, behind, bicycle): 1141
# (person, in_front_of, bicycle): 1141
# (person, watch, bicycle): 1137
# (person, away, bicycle): 1085
# (person, beneath, screen/monitor): 1084
# (person, above, bicycle): 1082
# (person, hold, bottle): 1063
# (person, lean_on, bicycle): 1055
# (person, hold, bicycle): 1050
# (person, beneath, guitar): 1015
# (person, ride, bicycle): 995
# (person, next_to, handbag): 980
# (person, next_to, camera): 945
# (person, carry, ball/sports_ball): 941
# (person, next_to, car): 937
# (person, hug, ball/sports_ball): 936
# (person, in_front_of, camera): 931
# (person, in_front_of, car): 930
# (person, behind, car): 918
# (person, watch, car): 894
# (person, push, baby_seat): 848
# (person, next_to, backpack): 817
# (person, watch, dish): 815
# (person, in_front_of, backpack): 806
# (person, beneath, bottle): 765
# (person, away, car): 727
# (person, towards, car): 722
# (person, watch, handbag): 689
# (person, in_front_of, bench): 665
# (person, next_to, bench): 664
# (person, behind, bench): 662
# (person, push, bicycle): 656
# (person, behind, camera): 619
# (person, in_front_of, laptop): 618
# (person, next_to, cellphone): 607
# (person, in_front_of, cellphone): 605
# (person, ride, car): 604
# (person, touch, screen/monitor): 600
# (person, next_to, laptop): 598
# (person, watch, camera): 564
# (person, carry, backpack): 549
# (person, watch, laptop): 543
# (person, in_front_of, refrigerator): 541
# (person, next_to, refrigerator): 510
# (person, next_to, stool): 501
# (person, in_front_of, piano): 496
# (person, watch, piano): 496
# (person, in_front_of, horse): 479
# (person, next_to, horse): 479
# (person, next_to, cake): 466
# (person, above, bench): 465
# (person, watch, horse): 462
# (person, next_to, ski): 448
# (person, inside, car): 432
# (person, above, horse): 427
# (person, hold, dish): 425
# (person, in_front_of, electric_fan): 424
# (person, next_to, electric_fan): 422
# (person, next_to, faucet): 418
# (person, above, ski): 405
# (person, watch, vegetables): 396
# (person, next_to, vegetables): 396
# (person, hold, handbag): 393
# (person, next_to, sink): 386
# (person, hold, camera): 386
# (person, away, ski): 384
# (person, watch, cellphone): 383
# (person, ride, ski): 365
# (person, next_to, cat): 356
# (person, watch, cat): 356
# (person, in_front_of, cat): 356
# (person, behind, cat): 356
# (person, behind, suitcase): 354
# (person, next_to, suitcase): 354
# (person, hold, cellphone): 353
# (person, next_to, baby_walker): 351
# (person, towards, handbag): 348
# (person, lean_on, bench): 345
# (person, watch, fruits): 341
# (person, next_to, fruits): 341
# (person, bite, bottle): 340
# (person, hold, fruits): 339
# (person, ride, horse): 320
# (person, lean_on, baby_walker): 319
# (person, towards, dish): 315
# (person, above, baby_walker): 311
# (person, above, stool): 307
# (person, inside, baby_walker): 291
# (person, away, stool): 288
# (person, lean_on, stool): 279
# (person, drive, car): 272
# (person, above, watercraft): 261
# (person, next_to, bus/truck): 235
# (person, behind, bus/truck): 235
# (person, carry, handbag): 230
# (person, next_to, bat): 224
# (person, ride, watercraft): 222
# (person, watch, cake): 207
# (person, hold, bat): 204
# (person, next_to, motorcycle): 199
# (person, behind, motorcycle): 199
# (person, use, camera): 198
# (person, play(instrument), piano): 193
# (person, use, cellphone): 181
# (person, in_front_of, aircraft): 180
# (person, pull, horse): 159
# (person, above, motorcycle): 152
# (person, next_to, bread): 137
# (person, next_to, hamster/rat): 103
# (person, next_to, fish): 97
# (person, in_front_of, fish): 97
# (person, next_to, racket): 82
# (person, hold, racket): 82
# (person, bite, fruits): 82
# (person, inside, bus/truck): 69
# (person, watch, train): 67
# (person, lean_on, sink): 65
# (person, in_front_of, oven): 63
# (person, ride, train): 60
# (person, above, surfboard): 59
# (person, ride, surfboard): 59
# (person, inside, train): 57
# (person, drive, motorcycle): 57
# (person, pat, stool): 55
# (person, next_to, snake): 51
# (person, hold, snake): 51
# (person, watch, duck): 49
# (person, next_to, bird): 31
# (person, next_to, chicken): 31
# (person, in_front_of, tiger): 27
# (person, cut, vegetables): 1
# (person, beneath, stop_sign): 0

# %%
# Compute mAP
import numpy as np

def voc_ap(rec, prec):
    ap = 0.
    for t in np.arange(0., 1.1, 0.1):
        if np.sum(rec >= t) == 0:
            p = 0
        else:
            p = np.max(prec[rec >= t])
        ap = ap + p / 11.
    return ap

ap = np.zeros(len(tp))
max_recall = np.zeros(len(tp))

for i, triplet_class in tqdm(enumerate(tp.keys())):
    sum_gt_temp = sum_gt[triplet_class]

    if sum_gt_temp == 0:
        continue
    tp_temp = np.asarray((tp[triplet_class]).copy())
    fp_temp = np.asarray((fp[triplet_class]).copy())
    res_num = len(tp_temp)
    if res_num == 0:
        continue
    scores_temp = np.asarray(scores[triplet_class].copy())
    sort_inds = np.argsort(-scores_temp) # sort decreasingly

    fp_temp = fp_temp[sort_inds]
    tp_temp = tp_temp[sort_inds]

    fp_temp = np.cumsum(fp_temp) 
    tp_temp = np.cumsum(tp_temp)

    rec = tp_temp / sum_gt_temp # recall
    prec = tp_temp / (fp_temp + tp_temp) # precision

    ap[i] = voc_ap(rec, prec)
    max_recall[i] = np.max(rec)

mAP = np.mean(ap[:])
m_rec = np.mean(max_recall[:])

print('------------------------------------------')
print('mAP: {:.5f} max recall: {:.5f}'.format(mAP, m_rec))
print('------------------------------------------')
# Out:
# 242it [00:00, 390.32it/s]
# ------------------------------------------
# mAP: 0.19833 max recall: 0.43974
# ------------------------------------------

# %%
# tp_counts = [len(value) for value in tp.values()]
tp_counts = []
total_count = 0
for value in tp.values():
    total_count += len(value)
    tp_counts.append(len(value))
tp_count_ratio = [count/total_count for count in tp_counts]

tp_keys = list(tp.keys())
unsorted_maps = []
for idx, classAP in enumerate(ap):
    s, p, o = tp_keys[idx]
    count = tp_counts[idx]
    count_ratio = tp_count_ratio[idx]
    unsorted_maps.append((classAP, (s, p, o), count, count_ratio))
    print(f'({idx_to_obj[s]}, {idx_to_pred[p]}, {idx_to_obj[o]}): mAP = {classAP}, count = {count} ({count_ratio*100:.3f}%)')
# Out:
# (person, next_to, screen/monitor): mAP = 0.20058823220965674, count = 2219 (0.200%)
# (person, towards, screen/monitor): mAP = 0.08345825213611152, count = 1837 (0.166%)
# (person, in_front_of, person): mAP = 0.33741593439472095, count = 95017 (8.577%)
# (person, watch, person): mAP = 0.008051869840487726, count = 70373 (6.352%)
# (person, next_to, person): mAP = 0.3717961442466646, count = 97363 (8.789%)
# (person, in_front_of, tiger): mAP = 1.0000000000000002, count = 27 (0.002%)
# (person, behind, person): mAP = 0.07642933098979286, count = 79212 (7.150%)
# (person, lean_on, sofa): mAP = 0.3413240455269326, count = 3072 (0.277%)
# (person, above, sofa): mAP = 0.1611379245846274, count = 3054 (0.276%)
# (person, hug, person): mAP = 0.0053475935828877, count = 24192 (2.184%)
# (person, speak_to, person): mAP = 0.0, count = 25161 (2.271%)
# (person, hold_hand_of, person): mAP = 0.00505050505050505, count = 23806 (2.149%)
# (person, pull, person): mAP = 9.441176748269905e-06, count = 12675 (1.144%)
# (person, next_to, cup): mAP = 0.7385376436256872, count = 2868 (0.259%)
# (person, next_to, bottle): mAP = 0.5065149316956257, count = 1723 (0.156%)
# (person, next_to, table): mAP = 0.6199880952839383, count = 6015 (0.543%)
# (person, next_to, chair): mAP = 0.22118398658443603, count = 4096 (0.370%)
# (person, next_to, dish): mAP = 0.7728013650981853, count = 1417 (0.128%)
# (person, towards, person): mAP = 0.0009090909090909091, count = 39913 (3.603%)
# (person, away, table): mAP = 0.0030353283489392606, count = 2828 (0.255%)
# (person, towards, table): mAP = 0.0038980239618883433, count = 2881 (0.260%)
# (person, next_to, cellphone): mAP = 0.6916685440725828, count = 607 (0.055%)
# (person, hold, cellphone): mAP = 0.008484848484848486, count = 353 (0.032%)
# (person, use, cellphone): mAP = 0.0, count = 181 (0.016%)
# (person, watch, cellphone): mAP = 0.0005790387955993052, count = 383 (0.035%)
# (person, next_to, toy): mAP = 0.628305005477822, count = 6881 (0.621%)
# (person, hold, toy): mAP = 0.004914004914004914, count = 6291 (0.568%)
# (person, in_front_of, sofa): mAP = 0.4515274436499482, count = 4188 (0.378%)
# (person, lean_on, baby_walker): mAP = 0.8602619084294547, count = 319 (0.029%)
# (person, inside, baby_walker): mAP = 0.0, count = 291 (0.026%)
# (person, next_to, ski): mAP = 0.3869604612985976, count = 448 (0.040%)
# (person, above, ski): mAP = 0.6040219925246603, count = 405 (0.037%)
# (person, behind, guitar): mAP = 0.37921764007729647, count = 5318 (0.480%)
# (person, play(instrument), guitar): mAP = 0.018181818181818184, count = 3270 (0.295%)
# (person, watch, guitar): mAP = 0.03308650780450961, count = 4074 (0.368%)
# (person, ride, ski): mAP = 0.001466275659824047, count = 365 (0.033%)
# (person, next_to, bat): mAP = 0.8034436202718787, count = 224 (0.020%)
# (person, hold, bat): mAP = 0.0012626262626262625, count = 204 (0.018%)
# (person, away, person): mAP = 0.0016835016835016834, count = 40690 (3.673%)
# (person, lean_on, table): mAP = 0.10269592476489028, count = 3657 (0.330%)
# (person, watch, camera): mAP = 0.0005717552887364208, count = 564 (0.051%)
# (person, use, camera): mAP = 0.0, count = 198 (0.018%)
# (person, lean_on, baby_seat): mAP = 0.4917232717492491, count = 1467 (0.132%)
# (person, above, baby_seat): mAP = 0.10528541226215646, count = 1489 (0.134%)
# (person, next_to, guitar): mAP = 0.36602480855666447, count = 5629 (0.508%)
# (person, in_front_of, guitar): mAP = 0.07516105005630658, count = 5351 (0.483%)
# (person, in_front_of, dog): mAP = 0.3322446993449304, count = 1788 (0.161%)
# (person, above, person): mAP = 0.0035687439743260613, count = 46614 (4.208%)
# (person, carry, person): mAP = 0.0011323196376577156, count = 22002 (1.986%)
# (person, watch, dog): mAP = 0.024045668824910247, count = 1774 (0.160%)
# (person, in_front_of, cellphone): mAP = 0.04903677758318739, count = 605 (0.055%)
# (person, watch, toy): mAP = 0.000961317722681359, count = 6863 (0.619%)
# (person, grab, toy): mAP = 0.0, count = 2915 (0.263%)
# (person, inside, baby_seat): mAP = 0.0017245627001724563, count = 1182 (0.107%)
# (person, above, chair): mAP = 0.2655299986965156, count = 1746 (0.158%)
# (person, watch, ball/sports_ball): mAP = 0.03243461617938065, count = 1543 (0.139%)
# (person, behind, chair): mAP = 0.06695073660543771, count = 3279 (0.296%)
# (person, away, car): mAP = 0.039634522001347566, count = 727 (0.066%)
# (person, in_front_of, car): mAP = 0.1528384279475983, count = 930 (0.084%)
# (person, next_to, ball/sports_ball): mAP = 0.6967407954308387, count = 1998 (0.180%)
# (person, towards, ball/sports_ball): mAP = 0.011363636363636364, count = 1335 (0.121%)
# (person, away, chair): mAP = 0.002104226983207875, count = 1660 (0.150%)
# (person, towards, car): mAP = 0.012491025202295466, count = 722 (0.065%)
# (person, behind, dog): mAP = 0.20393784512788243, count = 1774 (0.160%)
# (person, next_to, car): mAP = 0.1992869436586207, count = 937 (0.085%)
# (person, towards, dog): mAP = 0.0008616975441619992, count = 1724 (0.156%)
# (person, next_to, dog): mAP = 0.39796357382249964, count = 1792 (0.162%)
# (person, hold, ball/sports_ball): mAP = 0.0053475935828877, count = 1250 (0.113%)
# (person, caress, dog): mAP = 0.0007047216349541931, count = 1203 (0.109%)
# (person, lean_on, stool): mAP = 0.01515151515151515, count = 279 (0.025%)
# (person, above, stool): mAP = 0.7320265336140176, count = 307 (0.028%)
# (person, pat, stool): mAP = 0.0, count = 55 (0.005%)
# (person, next_to, stool): mAP = 0.45359520150011884, count = 501 (0.045%)
# (person, away, stool): mAP = 0.04797979797979798, count = 288 (0.026%)
# (person, next_to, electric_fan): mAP = 0.37961573730924897, count = 422 (0.038%)
# (person, push, person): mAP = 0.0, count = 14082 (1.271%)
# (person, touch, person): mAP = 1.903456677326024e-05, count = 12814 (1.157%)
# (person, hold, person): mAP = 0.0012987012987012987, count = 35204 (3.178%)
# (person, point_to, person): mAP = 0.0, count = 7764 (0.701%)
# (person, in_front_of, chair): mAP = 0.24000800066566827, count = 4057 (0.366%)
# (person, next_to, bird): mAP = 1.0000000000000002, count = 31 (0.003%)
# (person, next_to, backpack): mAP = 0.5947871002786368, count = 817 (0.074%)
# (person, carry, backpack): mAP = 0.018181818181818184, count = 549 (0.050%)
# (person, in_front_of, toy): mAP = 0.027658558051851686, count = 6880 (0.621%)
# (person, away, dog): mAP = 0.0012804097311139564, count = 1721 (0.155%)
# (person, beneath, toy): mAP = 0.09063734966886391, count = 4941 (0.446%)
# (person, lean_on, chair): mAP = 0.03052805280528053, count = 1464 (0.132%)
# (person, lean_on, person): mAP = 0.09117138202196184, count = 37531 (3.388%)
# (person, pat, person): mAP = 2.2619828541699653e-05, count = 8505 (0.768%)
# (person, behind, toy): mAP = 0.1132898208090933, count = 6877 (0.621%)
# (person, push, toy): mAP = 3.74419649543208e-05, count = 4166 (0.376%)
# (person, behind, car): mAP = 0.309107961488116, count = 918 (0.083%)
# (person, watch, dish): mAP = 0.0002230897936419409, count = 815 (0.074%)
# (person, hold, bottle): mAP = 0.010444394315362059, count = 1063 (0.096%)
# (person, next_to, cat): mAP = 0.4785520709939098, count = 356 (0.032%)
# (person, watch, cat): mAP = 0.007575757575757575, count = 356 (0.032%)
# (person, next_to, handbag): mAP = 0.6557716959003577, count = 980 (0.088%)
# (person, in_front_of, cat): mAP = 0.5681070068247577, count = 356 (0.032%)
# (person, next_to, cake): mAP = 0.5626394337853913, count = 466 (0.042%)
# (person, behind, cat): mAP = 0.1364079266857824, count = 356 (0.032%)
# (person, towards, chair): mAP = 0.0028708133971291866, count = 1642 (0.148%)
# (person, next_to, baby_seat): mAP = 0.371050237532981, count = 1563 (0.141%)
# (person, in_front_of, backpack): mAP = 0.15690548735629922, count = 806 (0.073%)
# (person, in_front_of, screen/monitor): mAP = 0.7833421949402053, count = 2292 (0.207%)
# (person, watch, screen/monitor): mAP = 0.02405808136467162, count = 2096 (0.189%)
# (person, kiss, person): mAP = 0.0, count = 7986 (0.721%)
# (person, lean_on, toy): mAP = 0.09300367767715148, count = 6009 (0.542%)
# (person, inside, toy): mAP = 0.0055607410799196925, count = 4334 (0.391%)
# (person, drive, toy): mAP = 0.0, count = 2950 (0.266%)
# (person, in_front_of, refrigerator): mAP = 0.3251554360611661, count = 541 (0.049%)
# (person, in_front_of, aircraft): mAP = 0.8060528585321696, count = 180 (0.016%)
# (person, in_front_of, laptop): mAP = 0.5612226937086966, count = 618 (0.056%)
# (person, above, bicycle): mAP = 0.5544663947988498, count = 1082 (0.098%)
# (person, ride, bicycle): mAP = 0.0009151921903599755, count = 995 (0.090%)
# (person, behind, camera): mAP = 0.23095188132004896, count = 619 (0.056%)
# (person, in_front_of, camera): mAP = 0.22760146639789364, count = 931 (0.084%)
# (person, next_to, camera): mAP = 0.39838021058755824, count = 945 (0.085%)
# (person, next_to, sink): mAP = 0.9056355783271737, count = 386 (0.035%)
# (person, next_to, faucet): mAP = 0.7364071335363203, count = 418 (0.038%)
# (person, next_to, hamster/rat): mAP = 0.5673216432450359, count = 103 (0.009%)
# (person, beneath, person): mAP = 0.0022079390362148015, count = 18998 (1.715%)
# (person, hold, cup): mAP = 0.000438266967192587, count = 1910 (0.172%)
# (person, above, toy): mAP = 0.11411112776994499, count = 6121 (0.553%)
# (person, towards, handbag): mAP = 0.004635502309920914, count = 348 (0.031%)
# (person, carry, handbag): mAP = 0.022727272727272728, count = 230 (0.021%)
# (person, watch, handbag): mAP = 0.00038037276531000376, count = 689 (0.062%)
# (person, above, watercraft): mAP = 0.8513561040351485, count = 261 (0.024%)
# (person, ride, watercraft): mAP = 0.0202020202020202, count = 222 (0.020%)
# (person, in_front_of, ball/sports_ball): mAP = 0.06509294755299076, count = 1960 (0.177%)
# (person, towards, cup): mAP = 0.009162934729393248, count = 1766 (0.159%)
# (person, away, cup): mAP = 0.001827809760088805, count = 1760 (0.159%)
# (person, away, toy): mAP = 0.006993006993006993, count = 6588 (0.595%)
# (person, above, horse): mAP = 0.31102087142700857, count = 427 (0.039%)
# (person, ride, horse): mAP = 0.0, count = 320 (0.029%)
# (person, in_front_of, baby_seat): mAP = 0.11318186661035748, count = 1563 (0.141%)
# (person, feed, person): mAP = 0.0, count = 11621 (1.049%)
# (person, press, person): mAP = 0.0, count = 12667 (1.143%)
# (person, press, toy): mAP = 0.0, count = 3913 (0.353%)
# (person, hit, person): mAP = 0.0, count = 9655 (0.872%)
# (person, hold, handbag): mAP = 0.0, count = 393 (0.035%)
# (person, next_to, sofa): mAP = 0.09364611087604346, count = 4156 (0.375%)
# (person, hold, camera): mAP = 0.008141112618724558, count = 386 (0.035%)
# (person, in_front_of, horse): mAP = 0.5922390714634748, count = 479 (0.043%)
# (person, pull, horse): mAP = 0.0, count = 159 (0.014%)
# (person, watch, horse): mAP = 0.00039439952672056796, count = 462 (0.042%)
# (person, next_to, horse): mAP = 0.3006522078906029, count = 479 (0.043%)
# (person, watch, laptop): mAP = 0.0, count = 543 (0.049%)
# (person, beneath, bottle): mAP = 0.0, count = 765 (0.069%)
# (person, bite, bottle): mAP = 0.0, count = 340 (0.031%)
# (person, pull, dog): mAP = 0.0, count = 1181 (0.107%)
# (person, in_front_of, electric_fan): mAP = 0.48171936758893286, count = 424 (0.038%)
# (person, carry, ball/sports_ball): mAP = 0.0, count = 941 (0.085%)
# (person, in_front_of, table): mAP = 0.013194815483758657, count = 5981 (0.540%)
# (person, behind, ball/sports_ball): mAP = 0.001450676982591876, count = 1638 (0.148%)
# (person, lift, person): mAP = 3.0172283740156294e-05, count = 8603 (0.777%)
# (person, caress, person): mAP = 3.105879429760537e-05, count = 15025 (1.356%)
# (person, towards, dish): mAP = 0.0, count = 315 (0.028%)
# (person, hold, dish): mAP = 0.00039872408293460925, count = 425 (0.038%)
# (person, wave_hand_to, person): mAP = 0.0, count = 7513 (0.678%)
# (person, inside, car): mAP = 0.5960182006535751, count = 432 (0.039%)
# (person, drive, car): mAP = 0.0, count = 272 (0.025%)
# (person, ride, car): mAP = 0.006418868487834005, count = 604 (0.055%)
# (person, towards, sofa): mAP = 0.0012916408486028739, count = 3280 (0.296%)
# (person, watch, cake): mAP = 0.0, count = 207 (0.019%)
# (person, touch, screen/monitor): mAP = 0.0, count = 600 (0.054%)
# (person, next_to, snake): mAP = 1.0000000000000002, count = 51 (0.005%)
# (person, hold, snake): mAP = 0.0, count = 51 (0.005%)
# (person, watch, cup): mAP = 0.0, count = 2455 (0.222%)
# (person, away, sofa): mAP = 0.002338276380829572, count = 3286 (0.297%)
# (person, away, ski): mAP = 0.008628220084422428, count = 384 (0.035%)
# (person, hold, guitar): mAP = 0.0048209366391184574, count = 2792 (0.252%)
# (person, next_to, bread): mAP = 0.7275723439176166, count = 137 (0.012%)
# (person, away, ball/sports_ball): mAP = 0.014598251188129576, count = 1325 (0.120%)
# (person, ride, train): mAP = 0.6835415030602195, count = 60 (0.005%)
# (person, inside, train): mAP = 0.22045454545454546, count = 57 (0.005%)
# (person, beneath, screen/monitor): mAP = 8.938946992044337e-05, count = 1084 (0.098%)
# (person, away, screen/monitor): mAP = 0.011337200519653161, count = 1851 (0.167%)
# (person, hold, screen/monitor): mAP = 0.10714285714285715, count = 1528 (0.138%)
# (person, touch, toy): mAP = 0.0, count = 3887 (0.351%)
# (person, above, surfboard): mAP = 0.9815100154083203, count = 59 (0.005%)
# (person, ride, surfboard): mAP = 0.007272727272727273, count = 59 (0.005%)
# (person, towards, toy): mAP = 0.00024770869457517957, count = 6597 (0.595%)
# (person, above, motorcycle): mAP = 0.5517192711516445, count = 152 (0.014%)
# (person, drive, motorcycle): mAP = 0.0, count = 57 (0.005%)
# (person, above, screen/monitor): mAP = 0.020242914979757085, count = 1473 (0.133%)
# (person, clean, person): mAP = 0.0006184291898577613, count = 7586 (0.685%)
# (person, lean_on, bicycle): mAP = 0.0003178639542275906, count = 1055 (0.095%)
# (person, watch, vegetables): mAP = 0.0, count = 396 (0.036%)
# (person, next_to, vegetables): mAP = 0.9048356351900904, count = 396 (0.036%)
# (person, in_front_of, oven): mAP = 0.990591016691103, count = 63 (0.006%)
# (person, hug, ball/sports_ball): mAP = 0.0005454545454545455, count = 936 (0.084%)
# (person, hold, dog): mAP = 0.00505050505050505, count = 1606 (0.145%)
# (person, behind, baby_seat): mAP = 0.04845568699252353, count = 1555 (0.140%)
# (person, next_to, refrigerator): mAP = 0.40909090909090917, count = 510 (0.046%)
# (person, cut, vegetables): mAP = 0.0, count = 1 (0.000%)
# (person, behind, suitcase): mAP = 0.7070107381795694, count = 354 (0.032%)
# (person, away, bicycle): mAP = 0.0015073009891662741, count = 1085 (0.098%)
# (person, push, bicycle): mAP = 0.0, count = 656 (0.059%)
# (person, next_to, bicycle): mAP = 0.14319022390923591, count = 1141 (0.103%)
# (person, next_to, motorcycle): mAP = 0.24590015462413967, count = 199 (0.018%)
# (person, point_to, toy): mAP = 0.0, count = 2577 (0.233%)
# (person, behind, bicycle): mAP = 0.09053795151113916, count = 1141 (0.103%)
# (person, watch, bicycle): mAP = 0.012185345518678852, count = 1137 (0.103%)
# (person, in_front_of, bicycle): mAP = 0.13740887175555508, count = 1141 (0.103%)
# (person, hold, bicycle): mAP = 0.0, count = 1050 (0.095%)
# (person, inside, bus/truck): mAP = 0.81814825105859, count = 69 (0.006%)
# (person, next_to, chicken): mAP = 0.9794721407624636, count = 31 (0.003%)
# (person, watch, fruits): mAP = 0.0, count = 341 (0.031%)
# (person, next_to, fruits): mAP = 0.7391014570027703, count = 341 (0.031%)
# (person, hold, fruits): mAP = 0.0, count = 339 (0.031%)
# (person, behind, screen/monitor): mAP = 0.03017070265978563, count = 2093 (0.189%)
# (person, next_to, laptop): mAP = 0.11063768056673705, count = 598 (0.054%)
# (person, next_to, fish): mAP = 0.802770920128617, count = 97 (0.009%)
# (person, next_to, baby_walker): mAP = 0.3730796763773482, count = 351 (0.032%)
# (person, next_to, bus/truck): mAP = 0.11353711790393013, count = 235 (0.021%)
# (person, next_to, racket): mAP = 0.8790257802001931, count = 82 (0.007%)
# (person, hold, racket): mAP = 0.0030303030303030303, count = 82 (0.007%)
# (person, next_to, bench): mAP = 0.2861955285071581, count = 664 (0.060%)
# (person, behind, bench): mAP = 0.32165239864463, count = 662 (0.060%)
# (person, ride, toy): mAP = 0.0, count = 5392 (0.487%)
# (person, behind, bus/truck): mAP = 0.34662371694457256, count = 235 (0.021%)
# (person, behind, sofa): mAP = 0.0, count = 3663 (0.331%)
# (person, behind, motorcycle): mAP = 0.16080402010050251, count = 199 (0.018%)
# (person, above, baby_walker): mAP = 0.018181818181818184, count = 311 (0.028%)
# (person, bite, toy): mAP = 0.0, count = 3020 (0.273%)
# (person, in_front_of, piano): mAP = 0.5789326669632197, count = 496 (0.045%)
# (person, play(instrument), piano): mAP = 0.0, count = 193 (0.017%)
# (person, lean_on, bench): mAP = 0.0005961251862891207, count = 345 (0.031%)
# (person, above, bench): mAP = 0.2356428642236026, count = 465 (0.042%)
# (person, watch, piano): mAP = 0.002840909090909091, count = 496 (0.045%)
# (person, lean_on, sink): mAP = 0.11764705882352941, count = 65 (0.006%)
# (person, above, table): mAP = 0.0014748441714733849, count = 3965 (0.358%)
# (person, in_front_of, fish): mAP = 0.6484107565936934, count = 97 (0.009%)
# (person, watch, train): mAP = 0.8171602528871338, count = 67 (0.006%)
# (person, next_to, suitcase): mAP = 0.556055683222866, count = 354 (0.032%)
# (person, bite, fruits): mAP = 0.0, count = 82 (0.007%)
# (person, beneath, stop_sign): mAP = 0.0, count = 0 (0.000%)
# (person, watch, duck): mAP = 0.0, count = 49 (0.004%)
# (person, watch, car): mAP = 0.03716843854187042, count = 894 (0.081%)
# (person, beneath, guitar): mAP = 0.0004722550177095632, count = 1015 (0.092%)
# (person, push, baby_seat): mAP = 0.0, count = 848 (0.077%)
# (person, in_front_of, bench): mAP = 0.06670639146754116, count = 665 (0.060%)

# %%
# Sorted by mAP
sorted_maps = sorted(unsorted_maps, reverse=True)
for idx, (classAP, (s, p, o), count, count_ratio) in enumerate(sorted_maps):
    if idx == 20:
        print('--')
    print(f'({idx_to_obj[s]}, {idx_to_pred[p]}, {idx_to_obj[o]}): mAP = {classAP:.5f}, count = {count} ({count_ratio*100:.3f}%)')
# Out:
# (person, in_front_of, tiger): mAP = 1.00000, count = 27 (0.002%)
# (person, next_to, snake): mAP = 1.00000, count = 51 (0.005%)
# (person, next_to, bird): mAP = 1.00000, count = 31 (0.003%)
# (person, in_front_of, oven): mAP = 0.99059, count = 63 (0.006%)
# (person, above, surfboard): mAP = 0.98151, count = 59 (0.005%)
# (person, next_to, chicken): mAP = 0.97947, count = 31 (0.003%)
# (person, next_to, sink): mAP = 0.90564, count = 386 (0.035%)
# (person, next_to, vegetables): mAP = 0.90484, count = 396 (0.036%)
# (person, next_to, racket): mAP = 0.87903, count = 82 (0.007%)
# (person, lean_on, baby_walker): mAP = 0.86026, count = 319 (0.029%)
# (person, above, watercraft): mAP = 0.85136, count = 261 (0.024%)
# (person, inside, bus/truck): mAP = 0.81815, count = 69 (0.006%)
# (person, watch, train): mAP = 0.81716, count = 67 (0.006%)
# (person, in_front_of, aircraft): mAP = 0.80605, count = 180 (0.016%)
# (person, next_to, bat): mAP = 0.80344, count = 224 (0.020%)
# (person, next_to, fish): mAP = 0.80277, count = 97 (0.009%)
# (person, in_front_of, screen/monitor): mAP = 0.78334, count = 2292 (0.207%)
# (person, next_to, dish): mAP = 0.77280, count = 1417 (0.128%)
# (person, next_to, fruits): mAP = 0.73910, count = 341 (0.031%)
# (person, next_to, cup): mAP = 0.73854, count = 2868 (0.259%)
# --
# (person, next_to, faucet): mAP = 0.73641, count = 418 (0.038%)
# (person, above, stool): mAP = 0.73203, count = 307 (0.028%)
# (person, next_to, bread): mAP = 0.72757, count = 137 (0.012%)
# (person, behind, suitcase): mAP = 0.70701, count = 354 (0.032%)
# (person, next_to, ball/sports_ball): mAP = 0.69674, count = 1998 (0.180%)
# (person, next_to, cellphone): mAP = 0.69167, count = 607 (0.055%)
# (person, ride, train): mAP = 0.68354, count = 60 (0.005%)
# (person, next_to, handbag): mAP = 0.65577, count = 980 (0.088%)
# (person, in_front_of, fish): mAP = 0.64841, count = 97 (0.009%)
# (person, next_to, toy): mAP = 0.62831, count = 6881 (0.621%)
# (person, next_to, table): mAP = 0.61999, count = 6015 (0.543%)
# (person, above, ski): mAP = 0.60402, count = 405 (0.037%)
# (person, inside, car): mAP = 0.59602, count = 432 (0.039%)
# (person, next_to, backpack): mAP = 0.59479, count = 817 (0.074%)
# (person, in_front_of, horse): mAP = 0.59224, count = 479 (0.043%)
# (person, in_front_of, piano): mAP = 0.57893, count = 496 (0.045%)
# (person, in_front_of, cat): mAP = 0.56811, count = 356 (0.032%)
# (person, next_to, hamster/rat): mAP = 0.56732, count = 103 (0.009%)
# (person, next_to, cake): mAP = 0.56264, count = 466 (0.042%)
# (person, in_front_of, laptop): mAP = 0.56122, count = 618 (0.056%)
# (person, next_to, suitcase): mAP = 0.55606, count = 354 (0.032%)
# (person, above, bicycle): mAP = 0.55447, count = 1082 (0.098%)
# (person, above, motorcycle): mAP = 0.55172, count = 152 (0.014%)
# (person, next_to, bottle): mAP = 0.50651, count = 1723 (0.156%)
# (person, lean_on, baby_seat): mAP = 0.49172, count = 1467 (0.132%)
# (person, in_front_of, electric_fan): mAP = 0.48172, count = 424 (0.038%)
# (person, next_to, cat): mAP = 0.47855, count = 356 (0.032%)
# (person, next_to, stool): mAP = 0.45360, count = 501 (0.045%)
# (person, in_front_of, sofa): mAP = 0.45153, count = 4188 (0.378%)
# (person, next_to, refrigerator): mAP = 0.40909, count = 510 (0.046%)
# (person, next_to, camera): mAP = 0.39838, count = 945 (0.085%)
# (person, next_to, dog): mAP = 0.39796, count = 1792 (0.162%)
# (person, next_to, ski): mAP = 0.38696, count = 448 (0.040%)
# (person, next_to, electric_fan): mAP = 0.37962, count = 422 (0.038%)
# (person, behind, guitar): mAP = 0.37922, count = 5318 (0.480%)
# (person, next_to, baby_walker): mAP = 0.37308, count = 351 (0.032%)
# (person, next_to, person): mAP = 0.37180, count = 97363 (8.789%)
# (person, next_to, baby_seat): mAP = 0.37105, count = 1563 (0.141%)
# (person, next_to, guitar): mAP = 0.36602, count = 5629 (0.508%)
# (person, behind, bus/truck): mAP = 0.34662, count = 235 (0.021%)
# (person, lean_on, sofa): mAP = 0.34132, count = 3072 (0.277%)
# (person, in_front_of, person): mAP = 0.33742, count = 95017 (8.577%)
# (person, in_front_of, dog): mAP = 0.33224, count = 1788 (0.161%)
# (person, in_front_of, refrigerator): mAP = 0.32516, count = 541 (0.049%)
# (person, behind, bench): mAP = 0.32165, count = 662 (0.060%)
# (person, above, horse): mAP = 0.31102, count = 427 (0.039%)
# (person, behind, car): mAP = 0.30911, count = 918 (0.083%)
# (person, next_to, horse): mAP = 0.30065, count = 479 (0.043%)
# (person, next_to, bench): mAP = 0.28620, count = 664 (0.060%)
# (person, above, chair): mAP = 0.26553, count = 1746 (0.158%)
# (person, next_to, motorcycle): mAP = 0.24590, count = 199 (0.018%)
# (person, in_front_of, chair): mAP = 0.24001, count = 4057 (0.366%)
# (person, above, bench): mAP = 0.23564, count = 465 (0.042%)
# (person, behind, camera): mAP = 0.23095, count = 619 (0.056%)
# (person, in_front_of, camera): mAP = 0.22760, count = 931 (0.084%)
# (person, next_to, chair): mAP = 0.22118, count = 4096 (0.370%)
# (person, inside, train): mAP = 0.22045, count = 57 (0.005%)
# (person, behind, dog): mAP = 0.20394, count = 1774 (0.160%)
# (person, next_to, screen/monitor): mAP = 0.20059, count = 2219 (0.200%)
# (person, next_to, car): mAP = 0.19929, count = 937 (0.085%)
# (person, above, sofa): mAP = 0.16114, count = 3054 (0.276%)
# (person, behind, motorcycle): mAP = 0.16080, count = 199 (0.018%)
# (person, in_front_of, backpack): mAP = 0.15691, count = 806 (0.073%)
# (person, in_front_of, car): mAP = 0.15284, count = 930 (0.084%)
# (person, next_to, bicycle): mAP = 0.14319, count = 1141 (0.103%)
# (person, in_front_of, bicycle): mAP = 0.13741, count = 1141 (0.103%)
# (person, behind, cat): mAP = 0.13641, count = 356 (0.032%)
# (person, lean_on, sink): mAP = 0.11765, count = 65 (0.006%)
# (person, above, toy): mAP = 0.11411, count = 6121 (0.553%)
# (person, next_to, bus/truck): mAP = 0.11354, count = 235 (0.021%)
# (person, behind, toy): mAP = 0.11329, count = 6877 (0.621%)
# (person, in_front_of, baby_seat): mAP = 0.11318, count = 1563 (0.141%)
# (person, next_to, laptop): mAP = 0.11064, count = 598 (0.054%)
# (person, hold, screen/monitor): mAP = 0.10714, count = 1528 (0.138%)
# (person, above, baby_seat): mAP = 0.10529, count = 1489 (0.134%)
# (person, lean_on, table): mAP = 0.10270, count = 3657 (0.330%)
# (person, next_to, sofa): mAP = 0.09365, count = 4156 (0.375%)
# (person, lean_on, toy): mAP = 0.09300, count = 6009 (0.542%)
# (person, lean_on, person): mAP = 0.09117, count = 37531 (3.388%)
# (person, beneath, toy): mAP = 0.09064, count = 4941 (0.446%)
# (person, behind, bicycle): mAP = 0.09054, count = 1141 (0.103%)
# (person, towards, screen/monitor): mAP = 0.08346, count = 1837 (0.166%)
# (person, behind, person): mAP = 0.07643, count = 79212 (7.150%)
# (person, in_front_of, guitar): mAP = 0.07516, count = 5351 (0.483%)
# (person, behind, chair): mAP = 0.06695, count = 3279 (0.296%)
# (person, in_front_of, bench): mAP = 0.06671, count = 665 (0.060%)
# (person, in_front_of, ball/sports_ball): mAP = 0.06509, count = 1960 (0.177%)
# (person, in_front_of, cellphone): mAP = 0.04904, count = 605 (0.055%)
# (person, behind, baby_seat): mAP = 0.04846, count = 1555 (0.140%)
# (person, away, stool): mAP = 0.04798, count = 288 (0.026%)
# (person, away, car): mAP = 0.03963, count = 727 (0.066%)
# (person, watch, car): mAP = 0.03717, count = 894 (0.081%)
# (person, watch, guitar): mAP = 0.03309, count = 4074 (0.368%)
# (person, watch, ball/sports_ball): mAP = 0.03243, count = 1543 (0.139%)
# (person, lean_on, chair): mAP = 0.03053, count = 1464 (0.132%)
# (person, behind, screen/monitor): mAP = 0.03017, count = 2093 (0.189%)
# (person, in_front_of, toy): mAP = 0.02766, count = 6880 (0.621%)
# (person, watch, screen/monitor): mAP = 0.02406, count = 2096 (0.189%)
# (person, watch, dog): mAP = 0.02405, count = 1774 (0.160%)
# (person, carry, handbag): mAP = 0.02273, count = 230 (0.021%)
# (person, above, screen/monitor): mAP = 0.02024, count = 1473 (0.133%)
# (person, ride, watercraft): mAP = 0.02020, count = 222 (0.020%)
# (person, play(instrument), guitar): mAP = 0.01818, count = 3270 (0.295%)
# (person, carry, backpack): mAP = 0.01818, count = 549 (0.050%)
# (person, above, baby_walker): mAP = 0.01818, count = 311 (0.028%)
# (person, lean_on, stool): mAP = 0.01515, count = 279 (0.025%)
# (person, away, ball/sports_ball): mAP = 0.01460, count = 1325 (0.120%)
# (person, in_front_of, table): mAP = 0.01319, count = 5981 (0.540%)
# (person, towards, car): mAP = 0.01249, count = 722 (0.065%)
# (person, watch, bicycle): mAP = 0.01219, count = 1137 (0.103%)
# (person, towards, ball/sports_ball): mAP = 0.01136, count = 1335 (0.121%)
# (person, away, screen/monitor): mAP = 0.01134, count = 1851 (0.167%)
# (person, hold, bottle): mAP = 0.01044, count = 1063 (0.096%)
# (person, towards, cup): mAP = 0.00916, count = 1766 (0.159%)
# (person, away, ski): mAP = 0.00863, count = 384 (0.035%)
# (person, hold, cellphone): mAP = 0.00848, count = 353 (0.032%)
# (person, hold, camera): mAP = 0.00814, count = 386 (0.035%)
# (person, watch, person): mAP = 0.00805, count = 70373 (6.352%)
# (person, watch, cat): mAP = 0.00758, count = 356 (0.032%)
# (person, ride, surfboard): mAP = 0.00727, count = 59 (0.005%)
# (person, away, toy): mAP = 0.00699, count = 6588 (0.595%)
# (person, ride, car): mAP = 0.00642, count = 604 (0.055%)
# (person, inside, toy): mAP = 0.00556, count = 4334 (0.391%)
# (person, hug, person): mAP = 0.00535, count = 24192 (2.184%)
# (person, hold, ball/sports_ball): mAP = 0.00535, count = 1250 (0.113%)
# (person, hold_hand_of, person): mAP = 0.00505, count = 23806 (2.149%)
# (person, hold, dog): mAP = 0.00505, count = 1606 (0.145%)
# (person, hold, toy): mAP = 0.00491, count = 6291 (0.568%)
# (person, hold, guitar): mAP = 0.00482, count = 2792 (0.252%)
# (person, towards, handbag): mAP = 0.00464, count = 348 (0.031%)
# (person, towards, table): mAP = 0.00390, count = 2881 (0.260%)
# (person, above, person): mAP = 0.00357, count = 46614 (4.208%)
# (person, away, table): mAP = 0.00304, count = 2828 (0.255%)
# (person, hold, racket): mAP = 0.00303, count = 82 (0.007%)
# (person, towards, chair): mAP = 0.00287, count = 1642 (0.148%)
# (person, watch, piano): mAP = 0.00284, count = 496 (0.045%)
# (person, away, sofa): mAP = 0.00234, count = 3286 (0.297%)
# (person, beneath, person): mAP = 0.00221, count = 18998 (1.715%)
# (person, away, chair): mAP = 0.00210, count = 1660 (0.150%)
# (person, away, cup): mAP = 0.00183, count = 1760 (0.159%)
# (person, inside, baby_seat): mAP = 0.00172, count = 1182 (0.107%)
# (person, away, person): mAP = 0.00168, count = 40690 (3.673%)
# (person, away, bicycle): mAP = 0.00151, count = 1085 (0.098%)
# (person, above, table): mAP = 0.00147, count = 3965 (0.358%)
# (person, ride, ski): mAP = 0.00147, count = 365 (0.033%)
# (person, behind, ball/sports_ball): mAP = 0.00145, count = 1638 (0.148%)
# (person, hold, person): mAP = 0.00130, count = 35204 (3.178%)
# (person, towards, sofa): mAP = 0.00129, count = 3280 (0.296%)
# (person, away, dog): mAP = 0.00128, count = 1721 (0.155%)
# (person, hold, bat): mAP = 0.00126, count = 204 (0.018%)
# (person, carry, person): mAP = 0.00113, count = 22002 (1.986%)
# (person, watch, toy): mAP = 0.00096, count = 6863 (0.619%)
# (person, ride, bicycle): mAP = 0.00092, count = 995 (0.090%)
# (person, towards, person): mAP = 0.00091, count = 39913 (3.603%)
# (person, towards, dog): mAP = 0.00086, count = 1724 (0.156%)
# (person, caress, dog): mAP = 0.00070, count = 1203 (0.109%)
# (person, clean, person): mAP = 0.00062, count = 7586 (0.685%)
# (person, lean_on, bench): mAP = 0.00060, count = 345 (0.031%)
# (person, watch, cellphone): mAP = 0.00058, count = 383 (0.035%)
# (person, watch, camera): mAP = 0.00057, count = 564 (0.051%)
# (person, hug, ball/sports_ball): mAP = 0.00055, count = 936 (0.084%)
# (person, beneath, guitar): mAP = 0.00047, count = 1015 (0.092%)
# (person, hold, cup): mAP = 0.00044, count = 1910 (0.172%)
# (person, hold, dish): mAP = 0.00040, count = 425 (0.038%)
# (person, watch, horse): mAP = 0.00039, count = 462 (0.042%)
# (person, watch, handbag): mAP = 0.00038, count = 689 (0.062%)
# (person, lean_on, bicycle): mAP = 0.00032, count = 1055 (0.095%)
# (person, towards, toy): mAP = 0.00025, count = 6597 (0.595%)
# (person, watch, dish): mAP = 0.00022, count = 815 (0.074%)
# (person, beneath, screen/monitor): mAP = 0.00009, count = 1084 (0.098%)
# (person, push, toy): mAP = 0.00004, count = 4166 (0.376%)
# (person, caress, person): mAP = 0.00003, count = 15025 (1.356%)
# (person, lift, person): mAP = 0.00003, count = 8603 (0.777%)
# (person, pat, person): mAP = 0.00002, count = 8505 (0.768%)
# (person, touch, person): mAP = 0.00002, count = 12814 (1.157%)
# (person, pull, person): mAP = 0.00001, count = 12675 (1.144%)
# (person, beneath, stop_sign): mAP = 0.00000, count = 0 (0.000%)
# (person, beneath, bottle): mAP = 0.00000, count = 765 (0.069%)
# (person, speak_to, person): mAP = 0.00000, count = 25161 (2.271%)
# (person, kiss, person): mAP = 0.00000, count = 7986 (0.721%)
# (person, feed, person): mAP = 0.00000, count = 11621 (1.049%)
# (person, wave_hand_to, person): mAP = 0.00000, count = 7513 (0.678%)
# (person, push, bicycle): mAP = 0.00000, count = 656 (0.059%)
# (person, push, baby_seat): mAP = 0.00000, count = 848 (0.077%)
# (person, push, person): mAP = 0.00000, count = 14082 (1.271%)
# (person, drive, motorcycle): mAP = 0.00000, count = 57 (0.005%)
# (person, drive, toy): mAP = 0.00000, count = 2950 (0.266%)
# (person, drive, car): mAP = 0.00000, count = 272 (0.025%)
# (person, bite, fruits): mAP = 0.00000, count = 82 (0.007%)
# (person, bite, bottle): mAP = 0.00000, count = 340 (0.031%)
# (person, bite, toy): mAP = 0.00000, count = 3020 (0.273%)
# (person, cut, vegetables): mAP = 0.00000, count = 1 (0.000%)
# (person, pull, horse): mAP = 0.00000, count = 159 (0.014%)
# (person, pull, dog): mAP = 0.00000, count = 1181 (0.107%)
# (person, inside, baby_walker): mAP = 0.00000, count = 291 (0.026%)
# (person, press, toy): mAP = 0.00000, count = 3913 (0.353%)
# (person, press, person): mAP = 0.00000, count = 12667 (1.143%)
# (person, use, cellphone): mAP = 0.00000, count = 181 (0.016%)
# (person, use, camera): mAP = 0.00000, count = 198 (0.018%)
# (person, grab, toy): mAP = 0.00000, count = 2915 (0.263%)
# (person, ride, horse): mAP = 0.00000, count = 320 (0.029%)
# (person, ride, toy): mAP = 0.00000, count = 5392 (0.487%)
# (person, play(instrument), piano): mAP = 0.00000, count = 193 (0.017%)
# (person, touch, screen/monitor): mAP = 0.00000, count = 600 (0.054%)
# (person, touch, toy): mAP = 0.00000, count = 3887 (0.351%)
# (person, point_to, toy): mAP = 0.00000, count = 2577 (0.233%)
# (person, point_to, person): mAP = 0.00000, count = 7764 (0.701%)
# (person, carry, ball/sports_ball): mAP = 0.00000, count = 941 (0.085%)
# (person, pat, stool): mAP = 0.00000, count = 55 (0.005%)
# (person, hold, snake): mAP = 0.00000, count = 51 (0.005%)
# (person, hold, fruits): mAP = 0.00000, count = 339 (0.031%)
# (person, hold, bicycle): mAP = 0.00000, count = 1050 (0.095%)
# (person, hold, handbag): mAP = 0.00000, count = 393 (0.035%)
# (person, hit, person): mAP = 0.00000, count = 9655 (0.872%)
# (person, towards, dish): mAP = 0.00000, count = 315 (0.028%)
# (person, behind, sofa): mAP = 0.00000, count = 3663 (0.331%)
# (person, watch, duck): mAP = 0.00000, count = 49 (0.004%)
# (person, watch, cup): mAP = 0.00000, count = 2455 (0.222%)
# (person, watch, cake): mAP = 0.00000, count = 207 (0.019%)
# (person, watch, fruits): mAP = 0.00000, count = 341 (0.031%)
# (person, watch, vegetables): mAP = 0.00000, count = 396 (0.036%)
# (person, watch, laptop): mAP = 0.00000, count = 543 (0.049%)

# %%
# Sorted by nb of occurrence
sorted_maps_by_count = sorted(unsorted_maps, key=lambda val:val[3], reverse=True)
for idx, (classAP, (s, p, o), count, count_ratio) in enumerate(sorted_maps_by_count):
    if idx == 20:
        print('--')
    print(f'({idx_to_obj[s]}, {idx_to_pred[p]}, {idx_to_obj[o]}): mAP = {classAP:.5f}, count = {count} ({count_ratio*100:.3f}%)')
# Out:
# (person, next_to, person): mAP = 0.37180, count = 97363 (8.789%)
# (person, in_front_of, person): mAP = 0.33742, count = 95017 (8.577%)
# (person, behind, person): mAP = 0.07643, count = 79212 (7.150%)
# (person, watch, person): mAP = 0.00805, count = 70373 (6.352%)
# (person, above, person): mAP = 0.00357, count = 46614 (4.208%)
# (person, away, person): mAP = 0.00168, count = 40690 (3.673%)
# (person, towards, person): mAP = 0.00091, count = 39913 (3.603%)
# (person, lean_on, person): mAP = 0.09117, count = 37531 (3.388%)
# (person, hold, person): mAP = 0.00130, count = 35204 (3.178%)
# (person, speak_to, person): mAP = 0.00000, count = 25161 (2.271%)
# (person, hug, person): mAP = 0.00535, count = 24192 (2.184%)
# (person, hold_hand_of, person): mAP = 0.00505, count = 23806 (2.149%)
# (person, carry, person): mAP = 0.00113, count = 22002 (1.986%)
# (person, beneath, person): mAP = 0.00221, count = 18998 (1.715%)
# (person, caress, person): mAP = 0.00003, count = 15025 (1.356%)
# (person, push, person): mAP = 0.00000, count = 14082 (1.271%)
# (person, touch, person): mAP = 0.00002, count = 12814 (1.157%)
# (person, pull, person): mAP = 0.00001, count = 12675 (1.144%)
# (person, press, person): mAP = 0.00000, count = 12667 (1.143%)
# (person, feed, person): mAP = 0.00000, count = 11621 (1.049%)
# --
# (person, hit, person): mAP = 0.00000, count = 9655 (0.872%)
# (person, lift, person): mAP = 0.00003, count = 8603 (0.777%)
# (person, pat, person): mAP = 0.00002, count = 8505 (0.768%)
# (person, kiss, person): mAP = 0.00000, count = 7986 (0.721%)
# (person, point_to, person): mAP = 0.00000, count = 7764 (0.701%)
# (person, clean, person): mAP = 0.00062, count = 7586 (0.685%)
# (person, wave_hand_to, person): mAP = 0.00000, count = 7513 (0.678%)
# (person, next_to, toy): mAP = 0.62831, count = 6881 (0.621%)
# (person, in_front_of, toy): mAP = 0.02766, count = 6880 (0.621%)
# (person, behind, toy): mAP = 0.11329, count = 6877 (0.621%)
# (person, watch, toy): mAP = 0.00096, count = 6863 (0.619%)
# (person, towards, toy): mAP = 0.00025, count = 6597 (0.595%)
# (person, away, toy): mAP = 0.00699, count = 6588 (0.595%)
# (person, hold, toy): mAP = 0.00491, count = 6291 (0.568%)
# (person, above, toy): mAP = 0.11411, count = 6121 (0.553%)
# (person, next_to, table): mAP = 0.61999, count = 6015 (0.543%)
# (person, lean_on, toy): mAP = 0.09300, count = 6009 (0.542%)
# (person, in_front_of, table): mAP = 0.01319, count = 5981 (0.540%)
# (person, next_to, guitar): mAP = 0.36602, count = 5629 (0.508%)
# (person, ride, toy): mAP = 0.00000, count = 5392 (0.487%)
# (person, in_front_of, guitar): mAP = 0.07516, count = 5351 (0.483%)
# (person, behind, guitar): mAP = 0.37922, count = 5318 (0.480%)
# (person, beneath, toy): mAP = 0.09064, count = 4941 (0.446%)
# (person, inside, toy): mAP = 0.00556, count = 4334 (0.391%)
# (person, in_front_of, sofa): mAP = 0.45153, count = 4188 (0.378%)
# (person, push, toy): mAP = 0.00004, count = 4166 (0.376%)
# (person, next_to, sofa): mAP = 0.09365, count = 4156 (0.375%)
# (person, next_to, chair): mAP = 0.22118, count = 4096 (0.370%)
# (person, watch, guitar): mAP = 0.03309, count = 4074 (0.368%)
# (person, in_front_of, chair): mAP = 0.24001, count = 4057 (0.366%)
# (person, above, table): mAP = 0.00147, count = 3965 (0.358%)
# (person, press, toy): mAP = 0.00000, count = 3913 (0.353%)
# (person, touch, toy): mAP = 0.00000, count = 3887 (0.351%)
# (person, behind, sofa): mAP = 0.00000, count = 3663 (0.331%)
# (person, lean_on, table): mAP = 0.10270, count = 3657 (0.330%)
# (person, away, sofa): mAP = 0.00234, count = 3286 (0.297%)
# (person, towards, sofa): mAP = 0.00129, count = 3280 (0.296%)
# (person, behind, chair): mAP = 0.06695, count = 3279 (0.296%)
# (person, play(instrument), guitar): mAP = 0.01818, count = 3270 (0.295%)
# (person, lean_on, sofa): mAP = 0.34132, count = 3072 (0.277%)
# (person, above, sofa): mAP = 0.16114, count = 3054 (0.276%)
# (person, bite, toy): mAP = 0.00000, count = 3020 (0.273%)
# (person, drive, toy): mAP = 0.00000, count = 2950 (0.266%)
# (person, grab, toy): mAP = 0.00000, count = 2915 (0.263%)
# (person, towards, table): mAP = 0.00390, count = 2881 (0.260%)
# (person, next_to, cup): mAP = 0.73854, count = 2868 (0.259%)
# (person, away, table): mAP = 0.00304, count = 2828 (0.255%)
# (person, hold, guitar): mAP = 0.00482, count = 2792 (0.252%)
# (person, point_to, toy): mAP = 0.00000, count = 2577 (0.233%)
# (person, watch, cup): mAP = 0.00000, count = 2455 (0.222%)
# (person, in_front_of, screen/monitor): mAP = 0.78334, count = 2292 (0.207%)
# (person, next_to, screen/monitor): mAP = 0.20059, count = 2219 (0.200%)
# (person, watch, screen/monitor): mAP = 0.02406, count = 2096 (0.189%)
# (person, behind, screen/monitor): mAP = 0.03017, count = 2093 (0.189%)
# (person, next_to, ball/sports_ball): mAP = 0.69674, count = 1998 (0.180%)
# (person, in_front_of, ball/sports_ball): mAP = 0.06509, count = 1960 (0.177%)
# (person, hold, cup): mAP = 0.00044, count = 1910 (0.172%)
# (person, away, screen/monitor): mAP = 0.01134, count = 1851 (0.167%)
# (person, towards, screen/monitor): mAP = 0.08346, count = 1837 (0.166%)
# (person, next_to, dog): mAP = 0.39796, count = 1792 (0.162%)
# (person, in_front_of, dog): mAP = 0.33224, count = 1788 (0.161%)
# (person, watch, dog): mAP = 0.02405, count = 1774 (0.160%)
# (person, behind, dog): mAP = 0.20394, count = 1774 (0.160%)
# (person, towards, cup): mAP = 0.00916, count = 1766 (0.159%)
# (person, away, cup): mAP = 0.00183, count = 1760 (0.159%)
# (person, above, chair): mAP = 0.26553, count = 1746 (0.158%)
# (person, towards, dog): mAP = 0.00086, count = 1724 (0.156%)
# (person, next_to, bottle): mAP = 0.50651, count = 1723 (0.156%)
# (person, away, dog): mAP = 0.00128, count = 1721 (0.155%)
# (person, away, chair): mAP = 0.00210, count = 1660 (0.150%)
# (person, towards, chair): mAP = 0.00287, count = 1642 (0.148%)
# (person, behind, ball/sports_ball): mAP = 0.00145, count = 1638 (0.148%)
# (person, hold, dog): mAP = 0.00505, count = 1606 (0.145%)
# (person, next_to, baby_seat): mAP = 0.37105, count = 1563 (0.141%)
# (person, in_front_of, baby_seat): mAP = 0.11318, count = 1563 (0.141%)
# (person, behind, baby_seat): mAP = 0.04846, count = 1555 (0.140%)
# (person, watch, ball/sports_ball): mAP = 0.03243, count = 1543 (0.139%)
# (person, hold, screen/monitor): mAP = 0.10714, count = 1528 (0.138%)
# (person, above, baby_seat): mAP = 0.10529, count = 1489 (0.134%)
# (person, above, screen/monitor): mAP = 0.02024, count = 1473 (0.133%)
# (person, lean_on, baby_seat): mAP = 0.49172, count = 1467 (0.132%)
# (person, lean_on, chair): mAP = 0.03053, count = 1464 (0.132%)
# (person, next_to, dish): mAP = 0.77280, count = 1417 (0.128%)
# (person, towards, ball/sports_ball): mAP = 0.01136, count = 1335 (0.121%)
# (person, away, ball/sports_ball): mAP = 0.01460, count = 1325 (0.120%)
# (person, hold, ball/sports_ball): mAP = 0.00535, count = 1250 (0.113%)
# (person, caress, dog): mAP = 0.00070, count = 1203 (0.109%)
# (person, inside, baby_seat): mAP = 0.00172, count = 1182 (0.107%)
# (person, pull, dog): mAP = 0.00000, count = 1181 (0.107%)
# (person, next_to, bicycle): mAP = 0.14319, count = 1141 (0.103%)
# (person, behind, bicycle): mAP = 0.09054, count = 1141 (0.103%)
# (person, in_front_of, bicycle): mAP = 0.13741, count = 1141 (0.103%)
# (person, watch, bicycle): mAP = 0.01219, count = 1137 (0.103%)
# (person, away, bicycle): mAP = 0.00151, count = 1085 (0.098%)
# (person, beneath, screen/monitor): mAP = 0.00009, count = 1084 (0.098%)
# (person, above, bicycle): mAP = 0.55447, count = 1082 (0.098%)
# (person, hold, bottle): mAP = 0.01044, count = 1063 (0.096%)
# (person, lean_on, bicycle): mAP = 0.00032, count = 1055 (0.095%)
# (person, hold, bicycle): mAP = 0.00000, count = 1050 (0.095%)
# (person, beneath, guitar): mAP = 0.00047, count = 1015 (0.092%)
# (person, ride, bicycle): mAP = 0.00092, count = 995 (0.090%)
# (person, next_to, handbag): mAP = 0.65577, count = 980 (0.088%)
# (person, next_to, camera): mAP = 0.39838, count = 945 (0.085%)
# (person, carry, ball/sports_ball): mAP = 0.00000, count = 941 (0.085%)
# (person, next_to, car): mAP = 0.19929, count = 937 (0.085%)
# (person, hug, ball/sports_ball): mAP = 0.00055, count = 936 (0.084%)
# (person, in_front_of, camera): mAP = 0.22760, count = 931 (0.084%)
# (person, in_front_of, car): mAP = 0.15284, count = 930 (0.084%)
# (person, behind, car): mAP = 0.30911, count = 918 (0.083%)
# (person, watch, car): mAP = 0.03717, count = 894 (0.081%)
# (person, push, baby_seat): mAP = 0.00000, count = 848 (0.077%)
# (person, next_to, backpack): mAP = 0.59479, count = 817 (0.074%)
# (person, watch, dish): mAP = 0.00022, count = 815 (0.074%)
# (person, in_front_of, backpack): mAP = 0.15691, count = 806 (0.073%)
# (person, beneath, bottle): mAP = 0.00000, count = 765 (0.069%)
# (person, away, car): mAP = 0.03963, count = 727 (0.066%)
# (person, towards, car): mAP = 0.01249, count = 722 (0.065%)
# (person, watch, handbag): mAP = 0.00038, count = 689 (0.062%)
# (person, in_front_of, bench): mAP = 0.06671, count = 665 (0.060%)
# (person, next_to, bench): mAP = 0.28620, count = 664 (0.060%)
# (person, behind, bench): mAP = 0.32165, count = 662 (0.060%)
# (person, push, bicycle): mAP = 0.00000, count = 656 (0.059%)
# (person, behind, camera): mAP = 0.23095, count = 619 (0.056%)
# (person, in_front_of, laptop): mAP = 0.56122, count = 618 (0.056%)
# (person, next_to, cellphone): mAP = 0.69167, count = 607 (0.055%)
# (person, in_front_of, cellphone): mAP = 0.04904, count = 605 (0.055%)
# (person, ride, car): mAP = 0.00642, count = 604 (0.055%)
# (person, touch, screen/monitor): mAP = 0.00000, count = 600 (0.054%)
# (person, next_to, laptop): mAP = 0.11064, count = 598 (0.054%)
# (person, watch, camera): mAP = 0.00057, count = 564 (0.051%)
# (person, carry, backpack): mAP = 0.01818, count = 549 (0.050%)
# (person, watch, laptop): mAP = 0.00000, count = 543 (0.049%)
# (person, in_front_of, refrigerator): mAP = 0.32516, count = 541 (0.049%)
# (person, next_to, refrigerator): mAP = 0.40909, count = 510 (0.046%)
# (person, next_to, stool): mAP = 0.45360, count = 501 (0.045%)
# (person, in_front_of, piano): mAP = 0.57893, count = 496 (0.045%)
# (person, watch, piano): mAP = 0.00284, count = 496 (0.045%)
# (person, in_front_of, horse): mAP = 0.59224, count = 479 (0.043%)
# (person, next_to, horse): mAP = 0.30065, count = 479 (0.043%)
# (person, next_to, cake): mAP = 0.56264, count = 466 (0.042%)
# (person, above, bench): mAP = 0.23564, count = 465 (0.042%)
# (person, watch, horse): mAP = 0.00039, count = 462 (0.042%)
# (person, next_to, ski): mAP = 0.38696, count = 448 (0.040%)
# (person, inside, car): mAP = 0.59602, count = 432 (0.039%)
# (person, above, horse): mAP = 0.31102, count = 427 (0.039%)
# (person, hold, dish): mAP = 0.00040, count = 425 (0.038%)
# (person, in_front_of, electric_fan): mAP = 0.48172, count = 424 (0.038%)
# (person, next_to, electric_fan): mAP = 0.37962, count = 422 (0.038%)
# (person, next_to, faucet): mAP = 0.73641, count = 418 (0.038%)
# (person, above, ski): mAP = 0.60402, count = 405 (0.037%)
# (person, watch, vegetables): mAP = 0.00000, count = 396 (0.036%)
# (person, next_to, vegetables): mAP = 0.90484, count = 396 (0.036%)
# (person, hold, handbag): mAP = 0.00000, count = 393 (0.035%)
# (person, next_to, sink): mAP = 0.90564, count = 386 (0.035%)
# (person, hold, camera): mAP = 0.00814, count = 386 (0.035%)
# (person, away, ski): mAP = 0.00863, count = 384 (0.035%)
# (person, watch, cellphone): mAP = 0.00058, count = 383 (0.035%)
# (person, ride, ski): mAP = 0.00147, count = 365 (0.033%)
# (person, next_to, cat): mAP = 0.47855, count = 356 (0.032%)
# (person, watch, cat): mAP = 0.00758, count = 356 (0.032%)
# (person, in_front_of, cat): mAP = 0.56811, count = 356 (0.032%)
# (person, behind, cat): mAP = 0.13641, count = 356 (0.032%)
# (person, behind, suitcase): mAP = 0.70701, count = 354 (0.032%)
# (person, next_to, suitcase): mAP = 0.55606, count = 354 (0.032%)
# (person, hold, cellphone): mAP = 0.00848, count = 353 (0.032%)
# (person, next_to, baby_walker): mAP = 0.37308, count = 351 (0.032%)
# (person, towards, handbag): mAP = 0.00464, count = 348 (0.031%)
# (person, lean_on, bench): mAP = 0.00060, count = 345 (0.031%)
# (person, watch, fruits): mAP = 0.00000, count = 341 (0.031%)
# (person, next_to, fruits): mAP = 0.73910, count = 341 (0.031%)
# (person, bite, bottle): mAP = 0.00000, count = 340 (0.031%)
# (person, hold, fruits): mAP = 0.00000, count = 339 (0.031%)
# (person, ride, horse): mAP = 0.00000, count = 320 (0.029%)
# (person, lean_on, baby_walker): mAP = 0.86026, count = 319 (0.029%)
# (person, towards, dish): mAP = 0.00000, count = 315 (0.028%)
# (person, above, baby_walker): mAP = 0.01818, count = 311 (0.028%)
# (person, above, stool): mAP = 0.73203, count = 307 (0.028%)
# (person, inside, baby_walker): mAP = 0.00000, count = 291 (0.026%)
# (person, away, stool): mAP = 0.04798, count = 288 (0.026%)
# (person, lean_on, stool): mAP = 0.01515, count = 279 (0.025%)
# (person, drive, car): mAP = 0.00000, count = 272 (0.025%)
# (person, above, watercraft): mAP = 0.85136, count = 261 (0.024%)
# (person, next_to, bus/truck): mAP = 0.11354, count = 235 (0.021%)
# (person, behind, bus/truck): mAP = 0.34662, count = 235 (0.021%)
# (person, carry, handbag): mAP = 0.02273, count = 230 (0.021%)
# (person, next_to, bat): mAP = 0.80344, count = 224 (0.020%)
# (person, ride, watercraft): mAP = 0.02020, count = 222 (0.020%)
# (person, watch, cake): mAP = 0.00000, count = 207 (0.019%)
# (person, hold, bat): mAP = 0.00126, count = 204 (0.018%)
# (person, next_to, motorcycle): mAP = 0.24590, count = 199 (0.018%)
# (person, behind, motorcycle): mAP = 0.16080, count = 199 (0.018%)
# (person, use, camera): mAP = 0.00000, count = 198 (0.018%)
# (person, play(instrument), piano): mAP = 0.00000, count = 193 (0.017%)
# (person, use, cellphone): mAP = 0.00000, count = 181 (0.016%)
# (person, in_front_of, aircraft): mAP = 0.80605, count = 180 (0.016%)
# (person, pull, horse): mAP = 0.00000, count = 159 (0.014%)
# (person, above, motorcycle): mAP = 0.55172, count = 152 (0.014%)
# (person, next_to, bread): mAP = 0.72757, count = 137 (0.012%)
# (person, next_to, hamster/rat): mAP = 0.56732, count = 103 (0.009%)
# (person, next_to, fish): mAP = 0.80277, count = 97 (0.009%)
# (person, in_front_of, fish): mAP = 0.64841, count = 97 (0.009%)
# (person, next_to, racket): mAP = 0.87903, count = 82 (0.007%)
# (person, hold, racket): mAP = 0.00303, count = 82 (0.007%)
# (person, bite, fruits): mAP = 0.00000, count = 82 (0.007%)
# (person, inside, bus/truck): mAP = 0.81815, count = 69 (0.006%)
# (person, watch, train): mAP = 0.81716, count = 67 (0.006%)
# (person, lean_on, sink): mAP = 0.11765, count = 65 (0.006%)
# (person, in_front_of, oven): mAP = 0.99059, count = 63 (0.006%)
# (person, ride, train): mAP = 0.68354, count = 60 (0.005%)
# (person, above, surfboard): mAP = 0.98151, count = 59 (0.005%)
# (person, ride, surfboard): mAP = 0.00727, count = 59 (0.005%)
# (person, inside, train): mAP = 0.22045, count = 57 (0.005%)
# (person, drive, motorcycle): mAP = 0.00000, count = 57 (0.005%)
# (person, pat, stool): mAP = 0.00000, count = 55 (0.005%)
# (person, next_to, snake): mAP = 1.00000, count = 51 (0.005%)
# (person, hold, snake): mAP = 0.00000, count = 51 (0.005%)
# (person, watch, duck): mAP = 0.00000, count = 49 (0.004%)
# (person, next_to, bird): mAP = 1.00000, count = 31 (0.003%)
# (person, next_to, chicken): mAP = 0.97947, count = 31 (0.003%)
# (person, in_front_of, tiger): mAP = 1.00000, count = 27 (0.002%)
# (person, cut, vegetables): mAP = 0.00000, count = 1 (0.000%)
# (person, beneath, stop_sign): mAP = 0.00000, count = 0 (0.000%)

# %%
from collections import defaultdict
pred_mean_AP = defaultdict(list)
pred_count = defaultdict(int)
total_count = 0
for classAP, (s, p, o), count, count_ratio in unsorted_maps:
    pred_mean_AP[p].append(classAP)
    pred_count[p] += count
    total_count += count
    
print('-- Predicate-wise mean AP --')
for idx, (p, APs) in enumerate(pred_mean_AP.items()):
#     if idx == 17:
#         print('--')
    print(f'{idx_to_pred[p]}: {sum(APs)/len(APs):5f} ({pred_count[p]*100/total_count:5f}%)')

print(len(pred_mean_AP))
# Out:
# -- Predicate-wise mean AP --
# next_to: 0.531144 (13.632700%)
# towards: 0.010933 (5.629028%)
# in_front_of: 0.376221 (12.405886%)
# watch: 0.045533 (8.717681%)
# behind: 0.189588 (9.919672%)
# lean_on: 0.194947 (4.988405%)
# above: 0.344456 (6.131903%)
# hug: 0.002947 (2.268220%)
# speak_to: 0.000000 (2.271199%)
# hold_hand_of: 0.005051 (2.148888%)
# pull: 0.000003 (1.265087%)
# away: 0.010996 (5.794486%)
# hold: 0.009457 (4.958076%)
# use: 0.000000 (0.034211%)
# inside: 0.273651 (0.574547%)
# play(instrument): 0.009091 (0.312593%)
# ride: 0.089977 (0.723668%)
# carry: 0.010510 (2.141305%)
# grab: 0.000000 (0.263127%)
# caress: 0.000368 (1.464847%)
# pat: 0.000011 (0.772682%)
# push: 0.000009 (1.782947%)
# touch: 0.000006 (1.561703%)
# point_to: 0.000000 (0.933447%)
# beneath: 0.015568 (2.419417%)
# kiss: 0.000000 (0.720869%)
# drive: 0.000000 (0.295984%)
# feed: 0.000000 (1.048989%)
# press: 0.000000 (1.496621%)
# hit: 0.000000 (0.871524%)
# bite: 0.000000 (0.310698%)
# lift: 0.000030 (0.776564%)
# wave_hand_to: 0.000000 (0.678173%)
# clean: 0.000618 (0.684763%)
# cut: 0.000000 (0.000090%)
# 35

# %%
list(tp.keys())[0]

# %%
ap[0]

# %%
len(tp.keys())

# %%
tp.keys()

# %%
tp[(0,3,17)]
